# %% [markdown]
# <a href="https://colab.research.google.com/github/stymchyshyn-spec/Homework-AI-1/blob/main/HW3_%D0%A2%D0%B8%D0%BC%D1%87%D0%B8%D1%88%D0%B8%D0%BD_%D0%A1%D0%BE%D1%84%D1%96%D1%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Твоє завдання - виконати аналіз даних у Google Colab на новому датасеті. Ми використаємо вбудований набір iris із бібліотеки seaborn. Потрібно виконати всі кроки аналізу, які ми вчили на лекції.

# %% [markdown]
# 1. Перед початком роботи зроби копію цього файлу у свій Google Drive через меню File → Save a copy in Drive. Працюй у своїй копії та виконуй завдання по черзі.

# %% [markdown]
# 2. Завантаж набір даних iris:

# %%
# Завантажуємо датасет iris
import seaborn as sns
df = sns.load_dataset('iris')

# %% [markdown]
# 3. Виведи перші 10 рядків таблиці.

# %%
# Показуємо перші 10 рядків таблиці
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %% [markdown]
# 4. Переглянь загальну інформацію про таблицю.

# %%
# Загальна інформація про таблицю
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# 5. Отримай статистичний опис числових колонок.

# %%
# Статистичний опис числових колонок
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# 6. Виведи тільки колонку species.

# %%
# Виведення тільки колонки з видом квітки
df['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %% [markdown]
# 7. Виведи рядки з індексами від 20 до 30 включно.

# %%
# Рядки з індексами від 20 до 30 включно
df.loc[20:30]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 20           5.4          3.4           1.7          0.2  setosa
# 21           5.1          3.7           1.5          0.4  setosa
# 22           4.6          3.6           1.0          0.2  setosa
# 23           5.1          3.3           1.7          0.5  setosa
# 24           4.8          3.4           1.9          0.2  setosa
# 25           5.0          3.0           1.6          0.2  setosa
# 26           5.0          3.4           1.6          0.4  setosa
# 27           5.2          3.5           1.5          0.2  setosa
# 28           5.2          3.4           1.4          0.2  setosa
# 29           4.7          3.2           1.6          0.2  setosa
# 30           4.8          3.1           1.6          0.2  setosa

# %% [markdown]
# 8. Використай зріз, щоб показати перші 3 колонки таблиці для перших 5 рядків.

# %%
# Перші три колонки таблиці для перших п’яти рядків
df.iloc[:5, :3]
# Out:
#    sepal_length  sepal_width  petal_length
# 0           5.1          3.5           1.4
# 1           4.9          3.0           1.4
# 2           4.7          3.2           1.3
# 3           4.6          3.1           1.5
# 4           5.0          3.6           1.4

# %% [markdown]
# 9. Відфільтруй усі рядки, де `sepal_length` більше за 6.

# %%
# Фільтрація: усі рядки, де sepal_length > 6
df[df['sepal_length'] > 6]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 56            6.3          3.3           4.7          1.6  versicolor
# ..            ...          ...           ...          ...         ...
# 144           6.7          3.3           5.7          2.5   virginica
# 145           6.7          3.0           5.2          2.3   virginica
# 146           6.3          2.5           5.0          1.9   virginica
# 147           6.5          3.0           5.2          2.0   virginica
# 148           6.2          3.4           5.4          2.3   virginica
#
# [61 rows x 5 columns]

# %% [markdown]
# 10. Зроби групування за колонкою `species` і порахуй середнє значення `petal_length` для кожного виду.

# %%
# Групування за видом і середнє значення petal_length
df.groupby('species')['petal_length'].mean()
# Out:
# species
# setosa        1.462
# versicolor    4.260
# virginica     5.552
# Name: petal_length, dtype: float64

# %% [markdown]
# 11. Створи нову колонку `sepal_ratio`, яка дорівнює відношенню `sepal_length` до `sepal_width`.

# %%
# Нова колонка sepal_ratio = sepal_length / sepal_width
df['sepal_ratio'] = df['sepal_length'] / df['sepal_width']

# %% [markdown]
# 12. Виведи перші 5 рядків таблиці з цією новою колонкою.

# %%
# Показати перші п’ять рядків з новою колонкою
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  sepal_ratio
# 0           5.1          3.5           1.4          0.2  setosa     1.457143
# 1           4.9          3.0           1.4          0.2  setosa     1.633333
# 2           4.7          3.2           1.3          0.2  setosa     1.468750
# 3           4.6          3.1           1.5          0.2  setosa     1.483871
# 4           5.0          3.6           1.4          0.2  setosa     1.388889

# %% [markdown]
# 13. Напиши короткий висновок у текстовій комірці Markdown. Які відмінності між видами вдалося побачити, чи є різниця у середніх значеннях.

# %% [markdown]
# ## Висновок
# setosa це найменша квітка,її довжина десь 5 а ширина 3. versicolor і virginica більші. В них довжина десь 6 а ширина теж 3. У їхніх середніх значеннях різниця не велика +- 0.5
# PS. Дякую за 10 в минулому завданні. У мене там було майже 500 слів (490 +-), можливо Ви не побачили ще другу сторінку :)
